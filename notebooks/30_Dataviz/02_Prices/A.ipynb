# %% [markdown]
# # Create Data Visualization for Energy Prices

# %% [markdown]
# https://www.esios.ree.es/es/analisis/10211?vis=1&start_date=01-01-2022T00%3A00&end_date=23-12-2022T23%3A55&compare_start_date=31-12-2021T00%3A00&groupby=day&compare_indicators=805,806,807,808,809,810,811,812,813,814,815,816,1277,10403,1286,1368

# %% [markdown]
# ## Create list with energy prices indicators

# %% [markdown]
# ## Generate the data with the `esios` library
#
# > You may need to change the `esios` library because it's made for p48 generation, not energy prices.

# %% [markdown]
# ### Get the `JSON` for one energy price

# %% [markdown]
# ### Process the `DataFrame`

# %% [markdown]
# ### Create an empty list

# %% [markdown]
# ### Process the data for all indicators

# %% [markdown]
# ### Concat all the `DataFrame`s within the list

# %%
# Out:
#                            Mercado Diario  Restricciones PBF  \
# datetime
# 2022-12-01 00:00:00+01:00          151.84               0.65
# 2022-12-01 01:00:00+01:00          132.22               0.99
# ...                                   ...                ...
# 2022-12-30 23:00:00+01:00            4.11               6.06
# 2022-12-31 00:00:00+01:00            1.06              15.49
#
#                            Restricciones TR  \
# datetime
# 2022-12-01 00:00:00+01:00              2.67
# 2022-12-01 01:00:00+01:00              1.46
# ...                                     ...
# 2022-12-30 23:00:00+01:00              0.00
# 2022-12-31 00:00:00+01:00              0.00
#
#                            Mercado intradiario (subastas MIBEL y continuo)  \
# datetime
# 2022-12-01 00:00:00+01:00                                            -0.02
# 2022-12-01 01:00:00+01:00                                             0.03
# ...                                                                    ...
# 2022-12-30 23:00:00+01:00                                            -0.02
# 2022-12-31 00:00:00+01:00                                             0.01
#
#                            Restricciones Intradiario  \
# datetime
# 2022-12-01 00:00:00+01:00                        0.0
# 2022-12-01 01:00:00+01:00                        0.0
# ...                                              ...
# 2022-12-30 23:00:00+01:00                        0.0
# 2022-12-31 00:00:00+01:00                        0.0
#
#                            Reserva Potencia Adicional Subir  Banda Secundaria  \
# datetime
# 2022-12-01 00:00:00+01:00                               0.0              0.83
# 2022-12-01 01:00:00+01:00                               0.0              2.21
# ...                                                     ...               ...
# 2022-12-30 23:00:00+01:00                               0.0              5.77
# 2022-12-31 00:00:00+01:00                               0.0              4.59
#
#                            Desvíos Medidos  Saldo Desvíos  \
# datetime
# 2022-12-01 00:00:00+01:00             0.20          -0.59
# 2022-12-01 01:00:00+01:00             0.34          -1.52
# ...                                    ...            ...
# 2022-12-30 23:00:00+01:00             0.12          -0.06
# 2022-12-31 00:00:00+01:00             0.09          -0.13
#
#                            Pagos por capacidad  Saldo P.O.14.6  \
# datetime
# 2022-12-01 00:00:00+01:00                  0.0            0.11
# 2022-12-01 01:00:00+01:00                  0.0           -0.29
# ...                                        ...             ...
# 2022-12-30 23:00:00+01:00                  0.4            0.00
# 2022-12-31 00:00:00+01:00                  0.0            0.02
#
#                            Fallo nominación UPG  \
# datetime
# 2022-12-01 00:00:00+01:00                   0.0
# 2022-12-01 01:00:00+01:00                   0.0
# ...                                         ...
# 2022-12-30 23:00:00+01:00                   0.0
# 2022-12-31 00:00:00+01:00                   0.0
#
#                            Servicio de interrumpibilidad  \
# datetime
# 2022-12-01 00:00:00+01:00                            0.0
# 2022-12-01 01:00:00+01:00                            0.0
# ...                                                  ...
# 2022-12-30 23:00:00+01:00                            0.0
# 2022-12-31 00:00:00+01:00                            0.0
#
#                            Mecanismo de ajuste RD-L 10/2022  \
# datetime
# 2022-12-01 00:00:00+01:00                             60.25
# 2022-12-01 01:00:00+01:00                             58.55
# ...                                                     ...
# 2022-12-30 23:00:00+01:00                              2.81
# 2022-12-31 00:00:00+01:00                              3.03
#
#                            Control factor de potencia  \
# datetime
# 2022-12-01 00:00:00+01:00                       -0.08
# 2022-12-01 01:00:00+01:00                       -0.08
# ...                                               ...
# 2022-12-30 23:00:00+01:00                       -0.08
# 2022-12-31 00:00:00+01:00                       -0.08
#
#                            Incumplimiento energía balance
# datetime
# 2022-12-01 00:00:00+01:00                           -0.06
# 2022-12-01 01:00:00+01:00                           -0.09
# ...                                                   ...
# 2022-12-30 23:00:00+01:00                           -0.03
# 2022-12-31 00:00:00+01:00                           -0.01
#
# [721 rows x 16 columns]

# %% [markdown]
# ## Compute the daily pricing

# %% [markdown]
# ## Melt the daily energy prices `DataFrame`

# %%
# Out:
#                      datetime                        variable       value
# 0   2022-12-01 00:00:00+01:00                  Mercado Diario  150.075000
# 1   2022-12-02 00:00:00+01:00                  Mercado Diario  127.620417
# ..                        ...                             ...         ...
# 494 2022-12-30 00:00:00+01:00  Incumplimiento energía balance   -0.051667
# 495 2022-12-31 00:00:00+01:00  Incumplimiento energía balance   -0.010000
#
# [496 rows x 3 columns]

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# ### Bar plot

# %% [markdown]
# #### Colors

# %% [markdown]
# #### Facets

# %% [markdown]
# ### Area plot

# %% [markdown]
# #### Colors

# %% [markdown]
# #### Facets

# %% [markdown]
# ### Line plot

# %% [markdown]
# #### Colors

# %% [markdown]
# #### Facets
